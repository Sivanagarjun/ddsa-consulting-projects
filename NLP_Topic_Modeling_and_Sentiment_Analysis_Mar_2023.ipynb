# %%
# Code snippet #0 - getting the data from web server
url = 'https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/Amazon%20reviews.txt'

# %%
# Code snippet #1- importing the 'requests' package to read the text data from the url
import requests
reviews = requests.get(url)
text = reviews.text

# %%
# Code snippet #2  Displaying the content of the reviews file
text

# %%
# Code snippet #3 Library to create a wordcloud
from wordcloud import WordCloud

# %%
# Code snippet #4 Library to plot the wordcloud
import matplotlib.pyplot as plt

#Generating the wordcloud :
wordcloud = WordCloud().generate(text)

#Plot the wordcloud :
plt.figure(figsize = (12, 12))
plt.imshow(wordcloud)

# %%
#  Code snippet #5 Sentiment Analysis
# First, we import the relevant modules from the NLTK library
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
#  Code snippet #6 - Initialize VADER so we can use it within our Python script
sid = SentimentIntensityAnalyzer()

# %%
#  Code snippet #7 - Calling the polarity_scores method on sid and passing in the message_text outputs a dictionary
# with negative, neutral, positive, and compound scores for the input text
scores = sid.polarity_scores(text)
scores
# Out:
# {'neg': 0.105, 'neu': 0.589, 'pos': 0.306, 'compound': 0.9892}
