# %%
# Code snippet #1
# Assigning the data url
data_url = 'https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/2021%20Texas%20High%20Schools%20Scores.csv'
data_url

# %%
# Code snippet #2
# Importing pandas package for data processing
import pandas as pd

# %%
# Code snippet 3
# Reading the data from the web URL
data = pd.read_csv(data_url)

# Displaying the data
data

# %%
# Code snippet 4
# Displaying the dataset size
data.shape

# %%
# Code snippet 5
# Displaying the dataset columns
data.columns

# %%
# Code snippet 6
# Displaying the descriptive stats
data.describe()

# %%
# Code snippet 7
# Installing dataprep package
# !pip install missingno

# %%
# Code snippet 8
# Importing dataprep package
import missingno as ms

# %%
# Code snippet 9
# Displaying the missing data report
ms.bar(data)

# %%
# Code snippet 10
# Installing dataprep package
# !pip install dataprep

# %%
# Code snippet 11
# Import dataprep package
from dataprep.eda import create_report

# %%
# Code snippet 12
# Creating a detailed EDA/Data profiling report using dataprep package
create_report(data).save()
