# %%
# Assigning the data url
data_url = 'https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/2021%20Texas%20High%20Schools%20Scores.csv'
data_url
# Out:
# 'https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/2021%20Texas%20High%20Schools%20Scores.csv'

# %%
# Importing pandas package for data processing
import pandas

# %%
# Reading the data from the web URL
data = pandas.read_csv(data_url)

# Displaying the data
data
# Out:
#                                   School  \
# 0                       Lasa High School
# 1     School For The Talented And Gifted
# 2      School Of Science And Engineering
# 3             Health Careers High School
# 4            Debakey H S For Health Prof
# ...                                  ...
# 1816                 W B Bizzell Academy
# 1817                 Phoenix High School
# 1818     Graduation Prep Academy Navarro
# 1819                              Munday
# 1820                    La Feria Academy
#
#                                              School URL  \
# 0     https://www.schooldigger.com/go/TX/schools/089...
# 1     https://www.schooldigger.com/go/TX/schools/162...
# 2     https://www.schooldigger.com/go/TX/schools/162...
# 3     https://www.schooldigger.com/go/TX/schools/331...
# 4     https://www.schooldigger.com/go/TX/schools/236...
# ...                                                 ...
# 1816  https://www.schooldigger.com/go/TX/schools/321...
# ...

# %%
# Displaying the dataset size/shape
data.shape
# Out:
# (1821, 25)

# %%
# Displaying the column names
data.columns
# Out:
# Index(['School', 'School URL', 'District', 'District URL', 'City', 'City URL',
#        'Zip', 'County', 'Phone', 'Is Title I', 'Is Charter', 'Is Magnet',
#        'Is Virtual', 'Number Students', 'Number Full-time Teachers',
#        'Student/Teacher Ratio', 'Percent Free/Disc Lunch',
#        'Percent Homes Rented', 'Percent of Unemployment',
#        'Percent Parents with Masters and above education',
#        'Percent parents with less than High School education',
#        'Percent Home Incomes with less than Median income',
#        'Home Prices Ranking', 'Community Health Ranking', 'Standard Score'],
#       dtype='object')

# %%
# Displaying the info of columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1821 entries, 0 to 1820
# Data columns (total 25 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   School                                                1821 non-null   object
#  1   School URL                                            1821 non-null   object
#  2   District                                              1821 non-null   object
#  3   District URL                                          1821 non-null   object
#  4   City                                                  1821 non-null   object
#  5   City URL                                              1821 non-null   object
#  6   Zip                                                   1821 non-null   int64
#  7   County                                                1821 non-null   object
# ...

# %%
# Displaying statistical descriptive summary of numerical variables
data.describe()
# Out:
#                 Zip  Number Students  Number Full-time Teachers  \
# count   1821.000000      1821.000000                1811.000000
# mean   77315.758375       916.175728                  61.561016
# std     1437.680272       992.964357                  57.729077
# min    75002.000000         0.000000                   0.000000
# 25%    76063.000000       205.000000                  19.600000
# 50%    77358.000000       456.000000                  36.200000
# 75%    78570.000000      1476.000000                  96.350000
# max    79938.000000     10450.000000                 288.600000
#
#        Student/Teacher Ratio  Percent Free/Disc Lunch  Percent Homes Rented  \
# count            1810.000000              1821.000000           1821.000000
# mean               13.560939                59.395936             10.565678
# std                 4.968011                24.166854             13.997171
# min                 0.300000                 0.000000              0.000000
# ...

# %%
# Code snippet 7
# Displaying the column names
data.columns
# Out:
# Index(['School', 'School URL', 'District', 'District URL', 'City', 'City URL',
#        'Zip', 'County', 'Phone', 'Is Title I', 'Is Charter', 'Is Magnet',
#        'Is Virtual', 'Number Students', 'Number Full-time Teachers',
#        'Student/Teacher Ratio', 'Percent Free/Disc Lunch',
#        'Percent Homes Rented', 'Percent of Unemployment',
#        'Percent Parents with Masters and above education',
#        'Percent parents with less than High School education',
#        'Percent Home Incomes with less than Median income',
#        'Home Prices Ranking', 'Community Health Ranking', 'Standard Score'],
#       dtype='object')

# %%
# Code snippet 8
# Creating predictors variable
predictors = ['District',  'City',
       'Zip', 'County', 'Is Title I', 'Is Charter', 'Is Magnet',
       'Is Virtual', 'Number Students', 'Number Full-time Teachers',
       'Student/Teacher Ratio', 'Percent Free/Disc Lunch',
       'Percent Homes Rented', 'Percent of Unemployment',
       'Percent Parents with Masters and above education',
       'Percent parents with less than High School education',
       'Percent Home Incomes with less than Median income',
       'Standard Score']

# Creating a subset of data with only predictor columns
data_pred = data[predictors]

#Displaying the pred_data columns
data_pred.columns
# Out:
# Index(['District', 'City', 'Zip', 'County', 'Is Title I', 'Is Charter',
#        'Is Magnet', 'Is Virtual', 'Number Students',
#        'Number Full-time Teachers', 'Student/Teacher Ratio',
#        'Percent Free/Disc Lunch', 'Percent Homes Rented',
#        'Percent of Unemployment',
#        'Percent Parents with Masters and above education',
#        'Percent parents with less than High School education',
#        'Percent Home Incomes with less than Median income', 'Standard Score'],
#       dtype='object')

# %%
# Code snippet 9
# Displaying the size of the predictors dataset
data_pred.shape
# Out:
# (1821, 18)

# %%
# Code snippet 10
# Installing Pycaret ML package
# !pip install -U --pre pycaret

# %%
# Code snippet 11
# Importing the regression components of pycaret
from pycaret.regression import *

# %%
# Code snippet 12
# Storing all categorical columns in a variable
cat_cols = ['District', 'City', 'Zip', 'County', 'Is Title I', 'Is Charter',
       'Is Magnet', 'Is Virtual']

# %%
# Code snippet 13
# Storing all numerical columns in a variable
num_cols = ['Number Students',
       'Number Full-time Teachers', 'Student/Teacher Ratio',
       'Percent Free/Disc Lunch', 'Percent Homes Rented',
       'Percent of Unemployment',
       'Percent Parents with Masters and above education',
       'Percent parents with less than High School education',
       'Percent Home Incomes with less than Median income']

# %%
# Code snippet 14
# Defining the target variable
y = 'Standard Score'

# %%
# Code snippet 15
# Setting up the Pycaret regression experiment
regression_model_setup = setup(data_pred,
                               target  = y,
                               categorical_features = cat_cols,
                               numeric_features= num_cols)
# Out:
# <style type="text/css">
# #T_192d1_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_192d1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_192d1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_192d1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_192d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_192d1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_192d1_row0_col1" class="data row0 col1" >3405</td>
#     </tr>
#     <tr>
#       <th id="T_192d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_192d1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_192d1_row1_col1" class="data row1 col1" >Standard Score</td>
#     </tr>
#     <tr>
#       <th id="T_192d1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Code snippet 16
# Creating an ML Model using the best algorithm
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_a3c9a th {
#   text-align: left;
# }
# ...

# %%
# Code snippet 17
# Importing the client data to make predictions
import pandas as pd
client_data = pd.read_csv('https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/TX%20High%20Schools%20-%20Client%20Data.csv')
client_data.columns
# Out:
# Index(['School', 'District', 'City', 'Zip', 'County', 'Phone', 'Is Title I',
#        'Is Charter', 'Is Magnet', 'Is Virtual', 'Number Students',
#        'Number Full-time Teachers', 'Student/Teacher Ratio',
#        'Percent Free/Disc Lunch', 'Percent Homes Rented',
#        'Percent of Unemployment',
#        'Percent Parents with Masters and above education',
#        'Percent parents with less than High School education',
#        'Percent Home Incomes with less than Median income',
#        'Home Prices Ranking', 'Community Health Ranking'],
#       dtype='object')

# %%
# Code snippet 18
# Predicting the standard scores for the client dataset
client_data_predictions = predict_model(best_model, data = client_data)
