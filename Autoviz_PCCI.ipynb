# %%
# Code snippet 1
# Installing AutoViz - for auto visualization
# !pip install autoviz

# %%
# Code snippet 2
# Import AutoViz class
from autoviz.AutoViz_Class import AutoViz_Class

# Instantiate/starting AutoViz_Class
AV = AutoViz_Class()

# %%
# Code snippet 3
# importing PCCI data
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/nvamsimohan/DallasDSA/refs/heads/main/PCCI%20Cases%20Readmit30%20Data.csv')

data.columns

# %%
# Optional code to select the predictors (taking out noise variables from the dataset)
# Example - Dropping 'Admit_Week', 'Admit_Month' - treating these as noise variables
 #predictors = data.drop(['Admit_Week', 'Admit_Month'], axis = 1)
 #predictors.columns
 #pass predictors in code snippet 4

# %%
# Code snippet 4
# Generating visuals using AutoViz
AV.AutoViz(data, verbose = 2, depVar='Readmit30')
